# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanka36/MLProblems/blob/main/Untitled95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://github.com/crux82/squad-it/raw/master/SQuAD_it-train.json.gz
# !wget https://github.com/crux82/squad-it/raw/master/SQuAD_it-test.json.gz
# Out:
# --2022-05-28 08:54:17--  https://github.com/crux82/squad-it/raw/master/SQuAD_it-train.json.gz
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/crux82/squad-it/master/SQuAD_it-train.json.gz [following]
# --2022-05-28 08:54:17--  https://raw.githubusercontent.com/crux82/squad-it/master/SQuAD_it-train.json.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7725286 (7.4M) [application/octet-stream]
# Saving to: ‘SQuAD_it-train.json.gz.1’
#
# SQuAD_it-train.json 100%[===================>]   7.37M  --.-KB/s    in 0.06s
#
# ...

# %%
# !gzip -dkv SQuAD_it-*.json.gz
# Out:
# SQuAD_it-test.json.gz:	 87.5% -- replaced with SQuAD_it-test.json
# SQuAD_it-train.json.gz:	 82.3% -- replaced with SQuAD_it-train.json

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.2 MB 7.6 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 50.5 MB/s
# ...
#      |████████████████████████████████| 86 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 596 kB 68.2 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 346 kB 8.5 MB/s
# ...
#      |████████████████████████████████| 212 kB 45.9 MB/s
# ...
#      |████████████████████████████████| 140 kB 54.5 MB/s
# ...
#      |████████████████████████████████| 86 kB 5.7 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 44.4 MB/s
# ...
#      |████████████████████████████████| 127 kB 47.0 MB/s
# ...
#      |████████████████████████████████| 271 kB 46.2 MB/s
# ...
#      |████████████████████████████████| 144 kB 44.0 MB/s
# ...
#      |████████████████████████████████| 94 kB 3.4 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.5.1
#     Uninstalling dill-0.3.5.1:
#       Successfully uninstalled dill-0.3.5.1
# ...

# %%
from datasets import load_dataset 
squad_it_dataset = load_dataset("json", data_files="SQuAD_it-train.json", field="data")
# Out:
# Using custom data configuration default-c5c43220e9343fe4
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-c5c43220e9343fe4/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
squad_it_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 442
#     })
# })

# %%
squad_it_dataset["train"]
# Out:
# Dataset({
#     features: ['title', 'paragraphs'],
#     num_rows: 442
# })

# %%
squad_it_dataset["train"][0]
# Out:
# {'paragraphs': [{'context': "Il terremoto del Sichuan del 2008 o il terremoto del Gran Sichuan, misurato a 8.0 Ms e 7.9 Mw, e si è verificato alle 02:28:01 PM China Standard Time all' epicentro (06:28:01 UTC) il 12 maggio nella provincia del Sichuan, ha ucciso 69.197 persone e lasciato 18.222 dispersi.",
#    'qas': [{'answers': [{'answer_start': 29, 'text': '2008'}],
#      'id': '56cdca7862d2951400fa6826',
#      'question': 'In quale anno si è verificato il terremoto nel Sichuan?'},
#     {'answers': [{'answer_start': 232, 'text': '69.197'}],
#      'id': '56cdca7862d2951400fa6828',
#      'question': 'Quante persone sono state uccise come risultato?'},
#     {'answers': [{'answer_start': 29, 'text': '2008'}],
#      'id': '56d4f9902ccc5a1400d833c0',
#      'question': 'Quale anno ha avuto luogo il terremoto del Sichuan?'},
#     {'answers': [{'answer_start': 78, 'text': '8.0 Ms e 7.9 Mw'}],
#      'id': '56d4f9902ccc5a1400d833c1',
# ...

# %%
data_files = {"train":"SQuAD_it-train.json","test":"SQuAD_it-test.json"}
squad_it_dataset = load_dataset("json", data_files=data_files, field="data")
squad_it_dataset
# Out:
# Using custom data configuration default-30c244ecfbe225ef
# ...
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-30c244ecfbe225ef/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 442
#     })
#     test: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 48
#     })
# })

# %%
data_files = {"train": "SQuAD_it-train.json.gz", "test": "SQuAD_it-test.json.gz"}
squad_it_dataset = load_dataset("json", data_files=data_files, field="data")
# Out:
# Using custom data configuration default-230c06bed54dbf44
# ...
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-230c06bed54dbf44/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
squad_it_dataset["test"][0]
# Out:
# {'paragraphs': [{'context': 'La crisi petrolifera del 1973 iniziò nell\' ottobre 1973 quando i membri dell\' Organizzazione dei Paesi esportatori di petrolio arabo (OAPEC, composta dai membri arabi dell\' OPEC più Egitto e Siria) proclamarono un embargo petrolifero. Alla fine dell\' embargo, nel marzo 1974, il prezzo del petrolio era salito da 3 dollari al barile a quasi 12 dollari a livello mondiale; i prezzi americani erano notevolmente più elevati. L\' embargo ha causato una crisi petrolifera, o "shock", con molti effetti a breve e lungo termine sulla politica globale e sull\' economia globale. Più tardi fu chiamato il "primo shock petrolifero", seguito dalla crisi petrolifera del 1979, definita il "secondo shock petrolifero".',
#    'qas': [{'answers': [{'answer_start': 43, 'text': 'ottobre 1973'},
#       {'answer_start': 43, 'text': 'ottobre 1973'},
#       {'answer_start': 43, 'text': 'ottobre 1973'},
#       {'answer_start': 43, 'text': 'ottobre'},
# ...

# %%
from datasets.dataset_dict import DatasetDict
dir(DatasetDict)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_check_values_features',
#  '_check_values_type',
#  'align_labels_with_mapping',
#  'cache_files',
#  'cast',
#  'cast_column',
#  'class_encode_column',
#  'cleanup_cache_files',
#  'clear',
#  'column_names',
#  'copy',
#  'data',
#  'filter',
#  'flatten',
#  'formatted_as',
#  'from_csv',
#  'from_json',
#  'from_parquet',
#  'from_text',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'load_from_disk',
#  'map',
#  'num_columns',
#  'num_rows',
#  'pop',
# ...

# %%
# !wget "https://archive.ics.uci.edu/ml/machine-learning-databases/00462/drugsCom_raw.zip"
# !unzip drugsCom_raw.zip
# Out:
# --2022-05-28 09:04:23--  https://archive.ics.uci.edu/ml/machine-learning-databases/00462/drugsCom_raw.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42989872 (41M) [application/x-httpd-php]
# Saving to: ‘drugsCom_raw.zip’
#
# drugsCom_raw.zip    100%[===================>]  41.00M  89.1MB/s    in 0.5s
#
# 2022-05-28 09:04:23 (89.1 MB/s) - ‘drugsCom_raw.zip’ saved [42989872/42989872]
#
# Archive:  drugsCom_raw.zip
#   inflating: drugsComTest_raw.tsv
#   inflating: drugsComTrain_raw.tsv

# %%
from datasets import load_dataset
datafiles = {"train_1":"drugsComTrain_raw.tsv","test_1":"drugsComTest_raw.tsv"}
drug_dataset = load_dataset("csv",data_files=datafiles , delimiter="\t")
# Out:
# Using custom data configuration default-92e45d9aac4d20d9
# ...
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-92e45d9aac4d20d9/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
drug_sample = drug_dataset["train_1"].shuffle(seed=42).select(range(1000))

# %%
datafiles.items
# Out:
# <function dict.items>

# %%
drug_dataset["train_1"][:3]
# Out:
# {'Unnamed: 0': [206461, 95260, 92703],
#  'condition': ['Left Ventricular Dysfunction', 'ADHD', 'Birth Control'],
#  'date': ['May 20, 2012', 'April 27, 2010', 'December 14, 2009'],
#  'drugName': ['Valsartan', 'Guanfacine', 'Lybrel'],
#  'rating': [9.0, 8.0, 5.0],
#  'review': ['"It has no side effect, I take it in combination of Bystolic 5 Mg and Fish Oil"',
# ...

# %%
type(drug_dataset)
# Out:
# datasets.dataset_dict.DatasetDict

# %%
def lowercase_condition(example):
  return { "condition":example["condition"].lower()}

# %%
drug_dataset.map(lowercase_condition)
# Out:
#   0%|          | 0/161297 [00:00<?, ?ex/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-0678ead08fa2> in <module>()
# ----> 1 drug_dataset.map(lowercase_condition)
#
# /usr/local/lib/python3.7/dist-packages/datasets/dataset_dict.py in map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_names, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, desc)
#     788                     desc=desc,
#     789                 )
# --> 790                 for k, dataset in self.items()
#     791             }
#     792         )
#
# /usr/local/lib/python3.7/dist-packages/datasets/dataset_dict.py in <dictcomp>(.0)
#     788                     desc=desc,
#     789                 )
# --> 790                 for k, dataset in self.items()
# ...

# %%
drug_dataset
# Out:
# DatasetDict({
#     train_1: Dataset({
#         features: ['Unnamed: 0', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount'],
#         num_rows: 161297
#     })
#     test_1: Dataset({
#         features: ['Unnamed: 0', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount'],
#         num_rows: 53766
#     })
# })

# %%
def filter_nones(x):
  return x["condition"] is not None

# %%
drug_dataset = drug_dataset.filter(filter_nones)
# Out:
# Loading cached processed dataset at /root/.cache/huggingface/datasets/csv/default-92e45d9aac4d20d9/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-40fec5fb3194ea9a.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/csv/default-92e45d9aac4d20d9/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-9fddce82d0c75fe9.arrow

# %%
drug_dataset["train_1"]["condition"][:3]
# Out:
# ['Left Ventricular Dysfunction', 'ADHD', 'Birth Control']

# %%
drug_dataset = drug_dataset.map(lowercase_condition)
# Out:
# ...
#   0%|          | 0/53471 [00:00<?, ?ex/s]

# %%
drug_dataset
# Out:
# DatasetDict({
#     train_1: Dataset({
#         features: ['Unnamed: 0', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount'],
#         num_rows: 160398
#     })
#     test_1: Dataset({
#         features: ['Unnamed: 0', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount'],
#         num_rows: 53471
#     })
# })

# %%
drug_dataset["train_1"]["condition"][:3]
# Out:
# ['left ventricular dysfunction', 'adhd', 'birth control']

# %%
def compute_review_length(example):
    return {"review_length": len(example["review"].split())}

# %%
drug_dataset =drug_dataset.map(compute_review_length)
# Out:
# Loading cached processed dataset at /root/.cache/huggingface/datasets/csv/default-92e45d9aac4d20d9/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-d46b70c056c8dfc7.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/csv/default-92e45d9aac4d20d9/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-fe688aada6bb6476.arrow

# %%
drug_dataset["train_1"][0]
# Out:
# {'Unnamed: 0': 206461,
#  'condition': 'left ventricular dysfunction',
#  'date': 'May 20, 2012',
#  'drugName': 'Valsartan',
#  'rating': 9.0,
#  'review': '"It has no side effect, I take it in combination of Bystolic 5 Mg and Fish Oil"',
#  'review_length': 17,
#  'usefulCount': 27}

# %%
drug_dataset["train_1"].sort("review_length")[:3]
# Out:
# Loading cached sorted indices for dataset at /root/.cache/huggingface/datasets/csv/default-92e45d9aac4d20d9/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-bb401c812694e624.arrow
# {'Unnamed: 0': [103488, 23627, 20558],
#  'condition': ['birth control', 'muscle spasm', 'pain'],
#  'date': ['November 4, 2008', 'March 24, 2017', 'August 20, 2016'],
#  'drugName': ['Loestrin 21 1 / 20', 'Chlorzoxazone', 'Nucynta'],
#  'rating': [10.0, 1.0, 6.0],
#  'review': ['"Excellent."', '"useless"', '"ok"'],
#  'review_length': [1, 1, 1],
#  'usefulCount': [5, 2, 10]}

# %%
drug_dataset = drug_dataset.filter(lambda x:x["review_length"]>30)
# Out:
# ...
#   0%|          | 0/54 [00:00<?, ?ba/s]

# %%
print(drug_dataset.num_rows)
# Out:
# {'train_1': 138514, 'test_1': 46108}

# %%
import html 
text = "I&#039;m a transformer called BERT"
html.unescape(text)
# Out:
# "I'm a transformer called BERT"

# %%
drug_dataset = drug_dataset.map(lambda x: {"review": html.unescape(x["review"])})
# Out:
# ...
#   0%|          | 0/46108 [00:00<?, ?ex/s]

# %%
new_drug_dataset = drug_dataset.map(lambda x:{'review':[html.unescape(o) for o in x["review"]]},batched=True)
# Out:
# ...
#   0%|          | 0/47 [00:00<?, ?ba/s]

# %%
new_drug_dataset
# Out:
# DatasetDict({
#     train_1: Dataset({
#         features: ['Unnamed: 0', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount', 'review_length'],
#         num_rows: 138514
#     })
#     test_1: Dataset({
#         features: ['Unnamed: 0', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount', 'review_length'],
#         num_rows: 46108
#     })
# })

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained('bert-base-cased')

def tokenize_function(examples):
  return tokenizer(examples["review"],truncation=True)
# Out:
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/208k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/426k [00:00<?, ?B/s]

# %%
# %time tokenized_dataset = drug_dataset.map(tokenize_function, batched=True)
# Out:
# ...
#   0%|          | 0/47 [00:00<?, ?ba/s]
# CPU times: user 1min 30s, sys: 1.02 s, total: 1min 31s
# Wall time: 58.4 s
